# %%
from statistics import mean
import numpy as np

# %%
xs = np.array([1,2,3,4,5],dtype=np.float64)
ys = np.array([5,4,6,5,6],dtype=np.float64)

# %%
def best_fit_slope_and_intercept(xs,ys):
    m = (((mean(xs)*mean(ys))-mean(xs*ys)) / ((mean(xs)*mean(xs))-mean(xs*xs)))
    b = mean(ys) - m*mean(xs)
    return m,b

m,b = best_fit_slope_and_intercept(xs,ys)
print(m,b)
# Out:
# 0.29999999999999893 4.300000000000003

# %%
regression_line=[]
for x in xs:
    regression_line.append((m*x)+b)
print(regression_line)
# Out:
# [4.600000000000002, 4.900000000000001, 5.2, 5.499999999999999, 5.799999999999998]

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')

plt.scatter(xs,ys,color='#003F73')
plt.plot(xs,regression_line)
plt.show()

# %%
predict_x = 2.5
predict_y = (m*predict_x) + b
print(predict_y)
# Out:
# 5.050000000000001

# %%
plt.scatter(predict_x, predict_y,color='#007F73',s=200,label='Predicted Data')
plt.scatter(xs,ys,color='#003F73',label='Data')
plt.plot(xs,regression_line,label='Regression Line')
plt.legend(loc=4)
plt.show()
